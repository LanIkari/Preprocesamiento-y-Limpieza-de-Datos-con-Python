# %% [markdown]
# # Planteamiento del problema
#
# * Generar un DF con una o varias tablas de una URL diferente a las vistas en la sesión
# * Generar un DF de alumnos o alumnas de la tabla alumnos de la base bdcolegio02 del servidor bd.arcelia.net

# %% [markdown]
# ## SQL

# %%
#Importamos pandas
import pandas as pd

# %%
#Armamos la conexion a la base de datos con todos los atributos
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02' #Cambio de Base de Datos
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)
#Comprobamos que nuetra conexion es correcta
str_conn
# Out:
# 'mysql+mysqlconnector://fesalu:bdfes2023@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password'

# %%
#Creacion del objeto de conexion
conn=create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM alumnos'''
df_mysql=pd.read_sql(sql,con=conn)

# %%
df_mysql
# Out:
#     clave_alu clave_admin ap_paterno ap_materno         nombre sexo  \
# 0    11030172        4812   BORBOLLA      RAMOS        ARGELIA    F
# 1    11030173        4849     CASTRO    MANCERA  KARLA MARIANA    F
# 2    11030177        4716   FERRUSCA    ANDRADE        OCTAVIO    M
# 3    11030178        4720     GARCIA      GOMEZ         RAFAEL    M
# 4    11030180        5380  GUTIERREZ     FLORES   CARLOS DAVID    M
# ..        ...         ...        ...        ...            ...  ...
# 803  12080002                 MEDINA  GUTIERREZ          OSCAR
# 804  14080001                  MEJIA    JIMENEZ          LUISA
# 805  14080002                  MEJIA    JIMENEZ          LUISA
# 806  14080003                  MEJIA    JIMENEZ          LUISA
# 807  14080004                  MEJIA    JIMENEZ          LUISA
#
#                    curp  peso  estatura                       direccion  \
# 0                        52.0      1.60             CLUB CAMPESTRE #867
# ...

# %%
sql = '''SELECT * FROM alumnos WHERE sexo = %s '''
df_mysql=pd.read_sql(sql,con=conn, params=['M'])#Obtenemos todos los alumnos que sean hombres
df_alumnos_Hombres=df_mysql #Creacion de un nuevo DATAFRAME

# %%
df_alumnos_Hombres
# Out:
#     clave_alu clave_admin  ap_paterno ap_materno          nombre sexo  \
# 0    11030177        4716    FERRUSCA    ANDRADE         OCTAVIO    M
# 1    11030178        4720      GARCIA      GOMEZ          RAFAEL    M
# 2    11030180        5380   GUTIERREZ     FLORES    CARLOS DAVID    M
# 3    11030188        4857    MARTINEZ     RIVERA    JAVIER JOSUE    M
# 4    11030199        4769     ROSALES     APREZA   NESTOR MARTIN    M
# ..        ...         ...         ...        ...             ...  ...
# 394  11080203              VILLAGRANA   BARRAGAN     CARLOS IVAN    M
# 395  11080204                AGUILLON   RESENDIZ            JOSE    M
# 396  11080206                    NAVA     TORRES  LEONARDO JESUS    M
# 397  11080207                   LOPEZ    AGUILAR          DANIEL    M
# 398  11080210                GUERRERO  COLOMBRES     ALDO ENRICO    M
#
#                    curp  peso  estatura                         direccion  \
# ...

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ## HTML

# %%
data_url='https://leagueoflegends.fandom.com/es/wiki/Lista_de_campeones'
df_lol=pd.read_html(data_url)#ubica todo lo que esta en formato tabular y lo encapsula en unA LISTA
print(type(df_lol))#Nos devuelve una lista de data frames
df_lol
# Out:
# <class 'list'>
# [         0                                                  1
#  0    Color                                         Definición
#  1    Verde                    Reducción del costo de EA o RP.
#  2     Rojo            Próxima reducción del costo de EA o RP.
#  3  Naranja  Incluido en el Paquete Edición Digital de Cole...
#  4     Azul                  Incluido en el Paquete Campeones.,
#                                 Campeón        Clases Fecha de Lanzamiento  \
#  0             Aatrox, la Espada Darkin        Coloso           2013-06-13
#  1      Ahri, la Vastaya de Nueve Colas        Ráfaga           2011-12-14
#  2            Akali, la Asesina Furtiva       Asesino           2010-05-11
#  3         Akshan, el Centinela Rebelde       Tirador           2021-07-22
#  4                Alistar, el Minotauro    Vanguardia           2009-02-21
#  ..                                 ...           ...                  ...
# ...

# %%
df_campeones=df_lol[1]#Obtenemos el primer elemento de la lista
df_campeones#Nuevo data frame de todos los campeones de Leag of Legends
# Out:
#                                Campeón        Clases Fecha de Lanzamiento  \
# 0             Aatrox, la Espada Darkin        Coloso           2013-06-13
# 1      Ahri, la Vastaya de Nueve Colas        Ráfaga           2011-12-14
# 2            Akali, la Asesina Furtiva       Asesino           2010-05-11
# 3         Akshan, el Centinela Rebelde       Tirador           2021-07-22
# 4                Alistar, el Minotauro    Vanguardia           2009-02-21
# ..                                 ...           ...                  ...
# 151     Zed, el Maestro de las Sombras       Asesino           2012-11-13
# 152   Ziggs, el Experto en Hexplosivos    Artillería           2012-02-01
# 153     Zilean, el Guardián del Tiempo  Especialista           2009-04-18
# 154     Zoe, el Aspecto del Crepúsculo        Ráfaga           2017-11-21
# 155  Zyra, el Despertar de las Espinas     Atrapador           2012-07-24
#
#     Último Cambio  Esencia Azul  Riot Points
# ...
